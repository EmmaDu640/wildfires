# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("darkgrid")

# %%
df_variables = pd.read_csv('_variable_descriptions.csv')

# %%
# Contains decription of features. 
pd.set_option('display.max_colwidth', None)
df_variables
# Out:
#                          Table                       Variable  \
# 0                        Fires                         FOD_ID
# 1                        Fires                         FPA_ID
# 2                        Fires             SOURCE_SYSTEM_TYPE
# 3                        Fires                  SOURCE_SYSTEM
# 4                        Fires          NWCG_REPORTING_AGENCY
# 5                        Fires         NWCG_REPORTING_UNIT_ID
# 6                        Fires       NWCG_REPORTING_UNIT_NAME
# 7                        Fires          SOURCE_REPORTING_UNIT
# 8                        Fires     SOURCE_REPORTING_UNIT_NAME
# 9                        Fires           LOCAL_FIRE_REPORT_ID
# 10                       Fires              LOCAL_INCIDENT_ID
# 11                       Fires                      FIRE_CODE
# 12                       Fires                      FIRE_NAME
# 13                       Fires  ICS_209_PLUS_INCIDENT_JOIN_ID
# ...

# %%
# keep the following columns:
keep_col=['FIRE_NAME','FIRE_YEAR', 'DISCOVERY_DATE', 'DISCOVERY_DOY', 'DISCOVERY_TIME', 
          'NWCG_CAUSE_CLASSIFICATION','NWCG_GENERAL_CAUSE', 'CONT_DATE', 
          'CONT_DOY', 'CONT_TIME', 'FIRE_SIZE', 'FIRE_SIZE_CLASS', 'LATITUDE', 'LONGITUDE', 'STATE',
          'NWCG_REPORTING_UNIT_NAME']

# %%
date_cols = ['DISCOVERY_DATE', 'CONT_DATE']
df = pd.read_csv('data.csv', usecols = keep_col, parse_dates=date_cols)
# Out:
# /var/folders/br/5csq0j7577g07ks6s_07bc800000gn/T/ipykernel_3569/4198525405.py:2: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data.csv', usecols = keep_col, parse_dates=date_cols)

# %%
df.head()
# Out:
#    NWCG_REPORTING_UNIT_NAME FIRE_NAME  FIRE_YEAR DISCOVERY_DATE  \
# 0    Plumas National Forest  FOUNTAIN       2005     2005-02-02
# 1  Eldorado National Forest    PIGEON       2004     2004-05-12
# 2  Eldorado National Forest     SLACK       2004     2004-05-31
# 3  Eldorado National Forest      DEER       2004     2004-06-28
# 4  Eldorado National Forest  STEVENOT       2004     2004-06-28
#
#    DISCOVERY_DOY  DISCOVERY_TIME NWCG_CAUSE_CLASSIFICATION  \
# 0             33          1300.0                     Human
# 1            133           845.0                   Natural
# 2            152          1921.0                     Human
# 3            180          1600.0                   Natural
# 4            180          1600.0                   Natural
#
#                            NWCG_GENERAL_CAUSE  CONT_DATE  CONT_DOY  CONT_TIME  \
# 0  Power generation/transmission/distribution 2005-02-02      33.0     1730.0
# ...

# %%
df.shape
# Out:
# (2303566, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2303566 entries, 0 to 2303565
# Data columns (total 16 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   NWCG_REPORTING_UNIT_NAME   object
#  1   FIRE_NAME                  object
#  2   FIRE_YEAR                  int64
#  3   DISCOVERY_DATE             datetime64[ns]
#  4   DISCOVERY_DOY              int64
#  5   DISCOVERY_TIME             float64
#  6   NWCG_CAUSE_CLASSIFICATION  object
#  7   NWCG_GENERAL_CAUSE         object
#  8   CONT_DATE                  datetime64[ns]
#  9   CONT_DOY                   float64
#  10  CONT_TIME                  float64
#  11  FIRE_SIZE                  float64
#  12  FIRE_SIZE_CLASS            object
#  13  LATITUDE                   float64
#  14  LONGITUDE                  float64
#  15  STATE                      object
# dtypes: datetime64[ns](2), float64(6), int64(2), object(6)
# memory usage: 281.2+ MB

# %%
df.head().T
# Out:
#                                                                     0  \
# NWCG_REPORTING_UNIT_NAME                       Plumas National Forest
# FIRE_NAME                                                    FOUNTAIN
# FIRE_YEAR                                                        2005
# DISCOVERY_DATE                                    2005-02-02 00:00:00
# DISCOVERY_DOY                                                      33
# DISCOVERY_TIME                                                 1300.0
# NWCG_CAUSE_CLASSIFICATION                                       Human
# NWCG_GENERAL_CAUSE         Power generation/transmission/distribution
# CONT_DATE                                         2005-02-02 00:00:00
# CONT_DOY                                                         33.0
# CONT_TIME                                                      1730.0
# FIRE_SIZE                                                         0.1
# ...

# %%
df.isna().sum()
# Out:
# NWCG_REPORTING_UNIT_NAME          0
# FIRE_NAME                    995415
# FIRE_YEAR                         0
# DISCOVERY_DATE                    0
# DISCOVERY_DOY                     0
# DISCOVERY_TIME               789095
# NWCG_CAUSE_CLASSIFICATION         0
# NWCG_GENERAL_CAUSE                0
# CONT_DATE                    894813
# CONT_DOY                     894813
# CONT_TIME                    990880
# FIRE_SIZE                         0
# FIRE_SIZE_CLASS                   0
# LATITUDE                          0
# LONGITUDE                         0
# STATE                             0
# dtype: int64

# %%
df.FIRE_YEAR.value_counts().plot(kind='bar')
plt.title('Fire by Year')
plt.show()

# %%
sns.countplot(x=df["FIRE_YEAR"])
plt.title('Fire by Year')
plt.xticks(rotation=90)
plt.show()

# %%
df.FIRE_SIZE.describe()
# Out:
# count    2.303566e+06
# mean     7.816088e+01
# std      2.630832e+03
# min      1.000000e-05
# 25%      1.000000e-01
# 50%      8.000000e-01
# 75%      3.000000e+00
# max      6.627000e+05
# Name: FIRE_SIZE, dtype: float64

# %%
df.FIRE_SIZE.max()
# Out:
# 662700.0

# %%
df[df['FIRE_SIZE']==df.FIRE_SIZE.max()]
# Out:
#               NWCG_REPORTING_UNIT_NAME       FIRE_NAME  FIRE_YEAR  \
# 2042980  Oklahoma Division of Forestry  OKS - STARBUCK       2017
#
#         DISCOVERY_DATE  DISCOVERY_DOY  DISCOVERY_TIME  \
# 2042980     2017-03-07             66          1237.0
#
#                        NWCG_CAUSE_CLASSIFICATION  \
# 2042980  Missing data/not specified/undetermined
#
#                               NWCG_GENERAL_CAUSE CONT_DATE  CONT_DOY  \
# 2042980  Missing data/not specified/undetermined       NaT       NaN
#
#          CONT_TIME  FIRE_SIZE FIRE_SIZE_CLASS  LATITUDE  LONGITUDE STATE
# 2042980        NaN   662700.0               G  36.77447  -100.1752    OK

# %%
#visualzie FIRE_SIZE
sns.violinplot(x=df.FIRE_SIZE)
plt.title('Fire Size')
plt.show()

# %%
#visualzie FIRE_SIZE
sns.violinplot(x=df.FIRE_SIZE)
plt.xlim([0,10])
plt.title('Fire Size')
plt.show()

# %%
df.NWCG_CAUSE_CLASSIFICATION.value_counts().plot(kind='barh')
plt.title('Cause Classification')
plt.show()

# %%
df.NWCG_GENERAL_CAUSE.value_counts().plot(kind='barh')
plt.title('General Cause')
plt.show()

# %%
df.FIRE_SIZE_CLASS.value_counts().plot(kind='bar')
plt.title('Fire SIZE Class')
plt.show()

# %%
#visualzie DISCOVERY_DOY
sns.displot(data=df, x='DISCOVERY_DOY', hue='FIRE_YEAR', kind='kde', fill=False)
plt.xlabel('DISCOVERY_DOY')
plt.xlim([0, 366])
plt.title('DISCOVERY_DOY')
plt.show()

# %%
eldorado=df[df['NWCG_REPORTING_UNIT_NAME']=='Eldorado National Forest']

# %%
eldorado.isna().sum()
# Out:
# NWCG_REPORTING_UNIT_NAME       0
# FIRE_NAME                    267
# FIRE_YEAR                      0
# DISCOVERY_DATE                 0
# DISCOVERY_DOY                  0
# DISCOVERY_TIME                55
# NWCG_CAUSE_CLASSIFICATION      0
# NWCG_GENERAL_CAUSE             0
# CONT_DATE                    168
# CONT_DOY                     168
# CONT_TIME                    223
# FIRE_SIZE                      0
# FIRE_SIZE_CLASS                0
# LATITUDE                       0
# LONGITUDE                      0
# STATE                          0
# dtype: int64

# %%
len(eldorado)
# Out:
# 2235

# %%
eldorado = eldorado[eldorado['CONT_TIME'].notna()]

# %%
eldorado.isna().sum()
# Out:
# NWCG_REPORTING_UNIT_NAME       0
# FIRE_NAME                    267
# FIRE_YEAR                      0
# DISCOVERY_DATE                 0
# DISCOVERY_DOY                  0
# DISCOVERY_TIME                 0
# NWCG_CAUSE_CLASSIFICATION      0
# NWCG_GENERAL_CAUSE             0
# CONT_DATE                      0
# CONT_DOY                       0
# CONT_TIME                      0
# FIRE_SIZE                      0
# FIRE_SIZE_CLASS                0
# LATITUDE                       0
# LONGITUDE                      0
# STATE                          0
# dtype: int64

# %%
sns.countplot(x=eldorado["FIRE_YEAR"])
plt.title('Eldorado Fire by Year')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# less fires in more recent years

# %%
#visualzie eldorado FIRE_SIZE
sns.violinplot(x=eldorado['FIRE_SIZE'])
plt.title('Eldorado Fire Size')
plt.show()

# %%
eldorado.NWCG_CAUSE_CLASSIFICATION.value_counts().plot(kind='barh')
plt.title('Eldorado Cause Classification')
plt.show()

# %%
eldorado.NWCG_GENERAL_CAUSE.value_counts().plot(kind='barh')
plt.title('Eldorado General Cause')
plt.show()

# %%
eldorado.FIRE_SIZE_CLASS.value_counts().plot(kind='bar')
plt.title('Eldorado Fire SIZE Class')
plt.show()

# %%
#visualzie DISCOVERY_DOY
sns.displot(data=eldorado, x='DISCOVERY_DOY', hue='FIRE_YEAR', kind='kde', fill=False)
plt.xlabel('DISCOVERY_DOY')
plt.xlim([0, 366])
plt.title('Eldorado DISCOVERY_DOY')
plt.show()

# %% [markdown]
# in ealier years, fires were more concentrated on the summerand fall months, in later years(darker lines), there are less fires and fires are more spread throughout the seasons

# %%
year_2004 = eldorado.loc[eldorado.FIRE_YEAR == 2004]
year_2004
# Out:
#          NWCG_REPORTING_UNIT_NAME  FIRE_NAME  FIRE_YEAR DISCOVERY_DATE  \
# 1        Eldorado National Forest     PIGEON       2004     2004-05-12
# 2        Eldorado National Forest      SLACK       2004     2004-05-31
# 3        Eldorado National Forest       DEER       2004     2004-06-28
# 4        Eldorado National Forest   STEVENOT       2004     2004-06-28
# 5        Eldorado National Forest     HIDDEN       2004     2004-06-30
# ...                           ...        ...        ...            ...
# 1062011  Eldorado National Forest  HOTCHKISS       2004     2004-04-20
# 1062446  Eldorado National Forest       MACE       2004     2004-08-15
# 1062447  Eldorado National Forest      CABLE       2004     2004-08-30
# 1062448  Eldorado National Forest       PARK       2004     2004-09-11
# 1062450  Eldorado National Forest       SAND       2004     2004-05-15
#
#          DISCOVERY_DOY  DISCOVERY_TIME NWCG_CAUSE_CLASSIFICATION  \
# ...

# %%
eldorado=eldorado.sort_values(by='DISCOVERY_DATE')
eldorado
# Out:
#          NWCG_REPORTING_UNIT_NAME   FIRE_NAME  FIRE_YEAR DISCOVERY_DATE  \
# 46912    Eldorado National Forest        SALT       1992     1992-02-04
# 47010    Eldorado National Forest    BROWNELL       1992     1992-04-22
# 46949    Eldorado National Forest      TANNER       1992     1992-05-02
# 46950    Eldorado National Forest         NaN       1992     1992-05-04
# 46978    Eldorado National Forest        LOON       1992     1992-05-06
# ...                           ...         ...        ...            ...
# 2167736  Eldorado National Forest       STONE       2019     2019-10-08
# 2168441  Eldorado National Forest  CREEK FIRE       2019     2019-10-19
# 2168439  Eldorado National Forest   LAKESHORE       2019     2019-10-31
# 2170474  Eldorado National Forest        SNOW       2019     2019-11-13
# 2167735  Eldorado National Forest  ICE 2 FIRE       2019     2019-11-15
#
#          DISCOVERY_DOY  DISCOVERY_TIME NWCG_CAUSE_CLASSIFICATION  \
# ...

# %%
eldorado['LA_LONG']=eldorado['LATITUDE'].astype(str)+eldorado['LONGITUDE'].astype(str)
eldorado['LA_LONG']
# Out:
# 46912            38.48-120.35833333
# 47010      38.77333333-120.33666667
# 46949      39.01666667-120.58333333
# 46950      39.01666667-120.53333333
# 46978             39.0-120.29166667
#                      ...
# 2167736    38.96694444-120.36527778
# 2168441    38.96833333-120.43472222
# 2168439    38.81861111-120.31722222
# 2170474    38.72277778-120.49333333
# 2167735    38.95722222-120.38472222
# Name: LA_LONG, Length: 2012, dtype: object

# %%
eldorado['LA_LONG'].duplicated().sum()
# Out:
# 59

# %%
dup_eldorado = eldorado[eldorado['LA_LONG'].duplicated() == True]
dup_eldorado
# Out:
#          NWCG_REPORTING_UNIT_NAME         FIRE_NAME  FIRE_YEAR DISCOVERY_DATE  \
# 46966    Eldorado National Forest               NaN       1992     1992-08-12
# 57016    Eldorado National Forest               NaN       1993     1993-07-19
# 57018    Eldorado National Forest         QUINTETTE       1993     1993-09-05
# 57020    Eldorado National Forest               NaN       1993     1993-09-12
# 57065    Eldorado National Forest               NaN       1993     1993-10-05
# 69478    Eldorado National Forest            SPRING       1994     1994-04-30
# 69459    Eldorado National Forest               NaN       1994     1994-05-31
# 69462    Eldorado National Forest               NaN       1994     1994-06-12
# 69474    Eldorado National Forest               NaN       1994     1994-09-28
# 80218    Eldorado National Forest            BLOUGH       1995     1995-05-27
# 80245    Eldorado National Forest              GOOF       1995     1995-06-24
# ...

# %%
dup_LA_LONG =dup_eldorado['LA_LONG']

# %%
dup=eldorado.loc[eldorado['LA_LONG'].isin(dup_LA_LONG)]
dup
# Out:
#          NWCG_REPORTING_UNIT_NAME  FIRE_NAME  FIRE_YEAR DISCOVERY_DATE  \
# 46955    Eldorado National Forest        NaN       1992     1992-06-24
# 46953    Eldorado National Forest        NaN       1992     1992-06-24
# 46958    Eldorado National Forest        NaN       1992     1992-06-25
# 46964    Eldorado National Forest        NaN       1992     1992-08-12
# 46966    Eldorado National Forest        NaN       1992     1992-08-12
# ...                           ...        ...        ...            ...
# 1635515  Eldorado National Forest       KIRK       2013     2013-10-27
# 1724381  Eldorado National Forest      WAGON       2014     2014-07-21
# 1888530  Eldorado National Forest  WENTWORTH       2017     2017-08-11
# 1886070  Eldorado National Forest      GERLE       2017     2017-08-11
# 2167736  Eldorado National Forest      STONE       2019     2019-10-08
#
#          DISCOVERY_DOY  DISCOVERY_TIME NWCG_CAUSE_CLASSIFICATION  \
# ...

# %%
df2 = dup[dup[['LA_LONG', 'DISCOVERY_DATE','DISCOVERY_TIME', 'CONT_TIME']].duplicated() == True]
df2
# Out:
#        NWCG_REPORTING_UNIT_NAME FIRE_NAME  FIRE_YEAR DISCOVERY_DATE  \
# 93793  Eldorado National Forest       VAN       1996     1996-08-12
# 37901  Eldorado National Forest    TURI 4       2009     2009-07-26
# 37904  Eldorado National Forest      TURI       2009     2009-07-26
# 37077  Eldorado National Forest    TURI 3       2009     2009-07-26
# 37913  Eldorado National Forest    TURI 7       2009     2009-07-26
# 37906  Eldorado National Forest    TURI 6       2009     2009-07-26
#
#        DISCOVERY_DOY  DISCOVERY_TIME NWCG_CAUSE_CLASSIFICATION  \
# 93793            225          1000.0                   Natural
# 37901            207          1200.0                     Human
# 37904            207          1200.0                     Human
# 37077            207          1200.0                     Human
# 37913            207          1200.0                     Human
# 37906            207          1200.0                     Human
#
# ...

# %%
dup_LA_LONG_1 =df2['LA_LONG']
dup_1=eldorado.loc[eldorado['LA_LONG'].isin(dup_LA_LONG_1)]
dup_1
# Out:
#        NWCG_REPORTING_UNIT_NAME FIRE_NAME  FIRE_YEAR DISCOVERY_DATE  \
# 93792  Eldorado National Forest      HORN       1996     1996-08-12
# 93793  Eldorado National Forest       VAN       1996     1996-08-12
# 37069  Eldorado National Forest    TURI 2       2009     2009-07-26
# 37901  Eldorado National Forest    TURI 4       2009     2009-07-26
# 37904  Eldorado National Forest      TURI       2009     2009-07-26
# 37077  Eldorado National Forest    TURI 3       2009     2009-07-26
# 37913  Eldorado National Forest    TURI 7       2009     2009-07-26
# 37906  Eldorado National Forest    TURI 6       2009     2009-07-26
#
#        DISCOVERY_DOY  DISCOVERY_TIME NWCG_CAUSE_CLASSIFICATION  \
# 93792            225          1000.0                   Natural
# 93793            225          1000.0                   Natural
# 37069            207          1200.0                     Human
# 37901            207          1200.0                     Human
# ...

# %%
eldorado= eldorado[~eldorado.index.isin(df2.index)]
eldorado
# Out:
#          NWCG_REPORTING_UNIT_NAME   FIRE_NAME  FIRE_YEAR DISCOVERY_DATE  \
# 46912    Eldorado National Forest        SALT       1992     1992-02-04
# 47010    Eldorado National Forest    BROWNELL       1992     1992-04-22
# 46949    Eldorado National Forest      TANNER       1992     1992-05-02
# 46950    Eldorado National Forest         NaN       1992     1992-05-04
# 46978    Eldorado National Forest        LOON       1992     1992-05-06
# ...                           ...         ...        ...            ...
# 2167736  Eldorado National Forest       STONE       2019     2019-10-08
# 2168441  Eldorado National Forest  CREEK FIRE       2019     2019-10-19
# 2168439  Eldorado National Forest   LAKESHORE       2019     2019-10-31
# 2170474  Eldorado National Forest        SNOW       2019     2019-11-13
# 2167735  Eldorado National Forest  ICE 2 FIRE       2019     2019-11-15
#
#          DISCOVERY_DOY  DISCOVERY_TIME NWCG_CAUSE_CLASSIFICATION  \
# ...

# %%
time = pd.DataFrame(pd.date_range(start='1992-01-01', end='2019-12-31'), columns=['date'])
time.head(3)
# Out:
#         date
# 0 1992-01-01
# 1 1992-01-02
# 2 1992-01-03

# %%
eldorado.to_csv('eldorado.csv', index=False)
